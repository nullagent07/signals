        print(perpetual_usdt_pairs)
                    
    finally:
        # Корректное закрытие клиента
        await exchange.close()

# Запуск анализа
await analyze_all_pairs()
# Out:
# ['10000000AIDOGE/USDT:USDT', '1000000BABYDOGE/USDT:USDT', '1000000MOG/USDT:USDT', '1000000PEIPEI/USDT:USDT', '10000COQ/USDT:USDT', '10000LADYS/USDT:USDT', '10000NFT/USDT:USDT', '10000SATS/USDT:USDT', '10000STARL/USDT:USDT', '10000WEN/USDT:USDT', '1000APU/USDT:USDT', '1000BEER/USDT:USDT', '1000BONK/USDT:USDT', '1000BTT/USDT:USDT', '1000FLOKI/USDT:USDT', '1000IQ50/USDT:USDT', '1000LUNC/USDT:USDT', '1000PEPE/USDT:USDT', '1000RATS/USDT:USDT', '1000TURBO/USDT:USDT', '1000XEC/USDT:USDT', '1CAT/USDT:USDT', '1INCH/USDT:USDT', 'AAVE/USDT:USDT', 'ACE/USDT:USDT', 'ACH/USDT:USDT', 'ADA/USDT:USDT', 'AERGO/USDT:USDT', 'AEVO/USDT:USDT', 'AGI/USDT:USDT', 'AGLD/USDT:USDT', 'AIOZ/USDT:USDT', 'AI/USDT:USDT', 'AKRO/USDT:USDT', 'AKT/USDT:USDT', 'ALGO/USDT:USDT', 'ALICE/USDT:USDT', 'ALPACA/USDT:USDT', 'ALPHA/USDT:USDT', 'ALT/USDT:USDT', 'AMB/USDT:USDT', 'ANKR/USDT:USDT', 'ANT/USDT:USDT', 'APE/USDT:USDT', 'API3/USDT:USDT', 'APT/USDT:USDT', 'ARB/USDT:USDT', 'ARKM/USDT:USDT', 'ARK/USDT:USDT', 'ARPA/USDT:USDT
# ...

# %%
import pandas as pd
import pandas_ta as ta
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from scipy import stats

df = pd.read_csv("EURUSD_Candlestick_1_Hour_BID_04.05.2003-15.04.2023.csv")
# df.tail()

df=df[df['volume']!=0]
df.head()
# df.reset_index(drop=True, inplace=True)

# df['EMA'] = ta.ema(df.close, length=150)
# df.tail()
# Out:
#                    Gmt time     open     high      low    close        volume
# 21  04.05.2003 21:00:00.000  1.12284  1.12338  1.12242  1.12305  2.905910e+07
# 22  04.05.2003 22:00:00.000  1.12274  1.12302  1.12226  1.12241  2.609180e+07
# 23  04.05.2003 23:00:00.000  1.12235  1.12235  1.12160  1.12169  2.924090e+07
# 24  05.05.2003 00:00:00.000  1.12161  1.12314  1.12154  1.12258  2.991480e+07
# 25  05.05.2003 01:00:00.000  1.12232  1.12262  1.12099  1.12140  2.837070e+07

# %%
import ccxt
from datetime import datetime, timedelta, timezone
import pandas as pd

# Настройка клиента Bybit
exchange = ccxt.bybit()

# Параметры для получения данных
symbol = 'BTC/USDT'  # Укажите нужную валютную пару
timeframe = '1h'  # Интервал свечей (например, '1h' - один час)
days = 2299  # Последний год
limit = 1000  # Максимальное количество данных за один запрос (может зависеть от биржи)

# Вычисление времени начала и конца
end_time = datetime.now(timezone.utc)
start_time = end_time - timedelta(days=days)
end_timestamp = int(end_time.timestamp() * 1000)
start_timestamp = int(start_time.timestamp() * 1000)

# Инициализация списка для хранения данных
all_ohlcv = []

# Загрузка данных
while start_timestamp < end_timestamp:
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=start_timestamp, limit=limit)
    if not ohlcv:
        break
    all_ohlcv.extend(ohlcv)
    # Обновление времени начала для следующего запроса
    start_timestamp = ohlcv[-1][0] + 1  # Устанавливаем начало на следующий период

# Конвертация в DataFrame
df = pd.DataFrame(all_ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

# Преобразование времени и сортировка
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
df = df.sort_values('timestamp')

# Сохранение в CSV файл
file_path = f'./CSV/BTCUSDT/BTC_USDT_Last_{days}_Days_Candlestik_{timeframe}.csv'
df.to_csv(file_path, index=False)

print(f"Данные успешно сохранены в файл: {file_path}")
# Out:
# Данные успешно сохранены в файл: ./CSV/BTCUSDT/BTC_USDT_Last_2299_Days_Candlestik_1h.csv

# %%
import ccxt
from datetime import datetime, timedelta, timezone
import pandas as pd

# Настройка клиента Bybit
exchange = ccxt.bybit()

# Параметры для получения данных
symbol = 'BTC/USDT'  # Укажите нужную валютную пару
timeframe = '1h'  # Интервал свечей (например, '1h' - один час)
days = 30  # Последний год
limit = 1000  # Максимальное количество данных за один запрос

# Вычисление времени начала и конца
end_time = datetime.now(timezone.utc)
start_time = end_time - timedelta(days=days)
end_timestamp = int(end_time.timestamp() * 1000)
start_timestamp = int(start_time.timestamp() * 1000)

# Инициализация списка для хранения данных
all_ohlcv = []

# Загрузка данных
while start_timestamp < end_timestamp:
    try:
        print(f"Fetching data from {start_timestamp} to {end_timestamp}")
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=start_timestamp, limit=limit)
        if not ohlcv:
            print("No data returned, breaking the loop")
            break
        all_ohlcv.extend(ohlcv)
        print(f"Fetched {len(ohlcv)} records")
        # Обновление времени начала для следующего запроса
        start_timestamp = ohlcv[-1][0] + 1  # Устанавливаем начало на следующий период
    except Exception as e:
        print(f"Ошибка при получении данных: {e}")
        break

# Проверка, были ли данные получены
if all_ohlcv:
    # Конвертация в DataFrame
    df = pd.DataFrame(all_ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

    # Преобразование времени и сортировка
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df = df.sort_values('timestamp')

    # Сохранение в CSV файл
    file_path = f'./BTC_USDT_Last_{days}_Days_Candlestick_{timeframe}.csv'
    df.to_csv(file_path, index=False)
    print(f"Данные успешно сохранены в файл: {file_path}")
else:
    print("No data was fetched.")

print("Script execution completed.")
# Out:
# Fetching data from 1717545273917 to 1720137273917
# Fetched 720 records
# Fetching data from 1720134000001 to 1720137273917
# No data returned, breaking the loop
# Данные успешно сохранены в файл: ./BTC_USDT_Last_30_Days_Candlestick_1h.csv
# Script execution completed.

# %%
import ccxt
from datetime import datetime, timedelta, timezone
import pandas as pd

# Настройка клиента Bybit
exchange = ccxt.bybit()

# Параметры для получения данных
symbol = 'BTC/USDT'  # Укажите нужную валютную пару
timeframe = '1h'  # Интервал свечей (например, '1h' - один час)
days = 2299  # Период, за который нужно получить данные
limit = 1000  # Максимальное количество данных за один запрос

# Вычисление времени начала и конца
end_time = datetime.now(timezone.utc)
start_time = end_time - timedelta(days=days)

# Инициализация списка для хранения данных
all_ohlcv = []

# Загрузка данных по месяцам
current_start_time = start_time
while current_start_time < end_time:
    current_end_time = current_start_time + timedelta(days=30)
    if current_end_time > end_time:
        current_end_time = end_time
    start_timestamp = int(current_start_time.timestamp() * 1000)
    end_timestamp = int(current_end_time.timestamp() * 1000)
    
    while start_timestamp < end_timestamp:
        try:
            print(f"Fetching data from {start_timestamp} to {end_timestamp}")
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=start_timestamp, limit=limit)
            if not ohlcv:
                print("No data returned, breaking the loop")
                break
            all_ohlcv.extend(ohlcv)
            print(f"Fetched {len(ohlcv)} records")
            # Обновление времени начала для следующего запроса
            start_timestamp = ohlcv[-1][0] + 1  # Устанавливаем начало на следующий период
        except Exception as e:
            print(f"Ошибка при получении данных: {e}")
            break
    
    current_start_time = current_end_time

# Проверка, были ли данные получены
if all_ohlcv:
    # Конвертация в DataFrame
    df = pd.DataFrame(all_ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

    # Преобразование времени и сортировка
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df = df.sort_values('timestamp')

    # Сохранение в CSV файл
    file_path = f'./BTC_USDT_Last_{days}_Days_Candlestick_{timeframe}.csv'
    df.to_csv(file_path, index=False)
    print(f"Данные успешно сохранены в файл: {file_path}")
else:
    print("No data was fetched.")

print("Script execution completed.")
# Out:
# Fetching data from 1521503737853 to 1524095737853
# No data returned, breaking the loop
# Fetching data from 1524095737853 to 1526687737853
# No data returned, breaking the loop
# Fetching data from 1526687737853 to 1529279737853
# No data returned, breaking the loop
# Fetching data from 1529279737853 to 1531871737853
# No data returned, breaking the loop
# Fetching data from 1531871737853 to 1534463737853
# No data returned, breaking the loop
# Fetching data from 1534463737853 to 1537055737853
# No data returned, breaking the loop
# Fetching data from 1537055737853 to 1539647737853
# No data returned, breaking the loop
# Fetching data from 1539647737853 to 1542239737853
# No data returned, breaking the loop
# Fetching data from 1542239737853 to 1544831737853
# No data returned, breaking the loop
# Fetching data from 1544831737853 to 1547423737853
# No data returned, breaking the loop
# Fetching data from 1547423737853 to 1550015737853
# No data returned, breaking the loop
# ...
